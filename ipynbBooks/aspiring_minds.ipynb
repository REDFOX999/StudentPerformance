# %%
import pandas as pd

# %%
import numpy as np
import os
cwd = os.getcwd()
os.chdir('/Users/shantanupatil/Desktop/Dataset/aspiring_minds/datachallenge_cods2016/datachallenge_cods2016/')

# %%
os.listdir('.')
# Out:
# ['data_description_doc.xlsx',
#  'Dataset Instructions.pdf',
#  'results.xlsx',
#  'test.xlsx',
#  'train.xlsx']

# %%
file ='train.xlsx'
xl = pd.ExcelFile(file)

# %%
print(xl.sheet_names)
# Out:
# ['Sheet1']

# %%
df = xl.parse('Sheet1')

# %%
df.size
# Out:
# 151924

# %%
df = df.drop(df.columns[[2,3,5]], axis=1)

# %%
df.head()
# Out:
#            ID   Salary               Designation Gender        DOB  \
# train  203097   420000   senior quality engineer      f 1990-02-19
# train  579905   500000         assistant manager      m 1989-10-04
# train  810601   325000          systems engineer      f 1992-08-03
# train  267447  1100000  senior software engineer      m 1989-12-05
# train  343523   200000                       get      m 1991-02-27
#
#        10percentage                         10board  12graduation  \
# train          84.3  board ofsecondary education,ap          2007
# train          85.4                            cbse          2007
# train          85.0                            cbse          2010
# train          85.6                            cbse          2007
# train          78.0                            cbse          2008
#
#        12percentage                             12board  \
# train          95.8  board of intermediate education,ap
# ...

# %%
df = df.drop(df.columns[4], axis=1)

# %%
list(df)
# Out:
# ['ID',
#  'Salary',
#  'Designation',
#  'Gender',
#  '10percentage',
#  '10board',
#  '12graduation',
#  '12percentage',
#  '12board',
#  'CollegeID',
#  'CollegeTier',
#  'Degree',
#  'Specialization',
#  'collegeGPA',
#  'CollegeCityID',
#  'CollegeCityTier',
#  'CollegeState',
#  'GraduationYear',
#  'English',
#  'Logical',
#  'Quant',
#  'Domain',
#  'ComputerProgramming',
#  'ElectronicsAndSemicon',
#  'ComputerScience',
#  'MechanicalEngg',
#  'ElectricalEngg',
#  'TelecomEngg',
#  'CivilEngg',
#  'conscientiousness',
#  'agreeableness',
#  'extraversion',
#  'nueroticism',
#  'openess_to_experience']

# %%
df = df.drop(df.columns[[9,14,16,17,22,23,24,25,26,27,28]], axis = 1)

# %%
list(df)
# Out:
# ['ID',
#  'Salary',
#  'Designation',
#  'Gender',
#  '10percentage',
#  '10board',
#  '12graduation',
#  '12percentage',
#  '12board',
#  'CollegeTier',
#  'Degree',
#  'Specialization',
#  'collegeGPA',
#  'CollegeCityTier',
#  'English',
#  'Logical',
#  'Quant',
#  'Domain',
#  'conscientiousness',
#  'agreeableness',
#  'extraversion',
#  'nueroticism',
#  'openess_to_experience']

# %%
df.groupby('Degree').size()
# Out:
# Degree
# B.Tech/B.E.      3700
# M.Sc. (Tech.)       2
# M.Tech./M.E.       53
# MCA               243
# dtype: int64

# %%
df
# Out:
#             ID   Salary                   Designation Gender  10percentage  \
# train   203097   420000       senior quality engineer      f         84.30
# train   579905   500000             assistant manager      m         85.40
# train   810601   325000              systems engineer      f         85.00
# train   267447  1100000      senior software engineer      m         85.60
# train   343523   200000                           get      m         78.00
# train  1027655   300000               system engineer      m         89.92
# train   947847   300000        java software engineer      m         86.08
# train   912934   400000           mechanical engineer      m         92.00
# train   552574   600000           electrical engineer      m         90.00
# train  1203363   230000              project engineer      m         77.00
# train    87291   600000          senior php developer      m         88.60
# ...

# %%
df2 = df['Salary'].rank(axis=0, method='average', numeric_only=None, na_option='keep', ascending=False, pct=False)

# %%
dfnew = pd.concat([df2, df], axis=1)

# %%
df.size
# Out:
# 91954

# %%
dfsucess = df['Salary']>=800000

# %%
dfsucess = df[dfsucess]

# %%
dfsucess[["Salary","Gender","10percentage","12percentage","CollegeTier","collegeGPA",'English',
 'Logical',
 'Quant',
 'Domain',
 'conscientiousness',
 'agreeableness',
 'extraversion',
 'nueroticism',
 'openess_to_experience']].describe()
# Out:
#              Salary  10percentage  12percentage  CollegeTier  collegeGPA  \
# count  6.300000e+01     63.000000     63.000000    63.000000   63.000000
# mean   1.386984e+06     79.580476     75.601429     1.714286   73.283333
# std    7.602231e+05     10.554252     11.915717     0.455383   12.234770
# min    8.000000e+05     53.000000     50.000000     1.000000    8.890000
# 25%    8.550000e+05     72.750000     67.600000     1.000000   67.400000
# 50%    1.100000e+06     82.400000     76.670000     2.000000   72.600000
# 75%    1.772500e+06     87.800000     86.625000     2.000000   79.950000
# max    4.000000e+06     97.760000     96.330000     2.000000   96.900000
#
#           English     Logical       Quant     Domain  conscientiousness  \
# count   63.000000   63.000000   63.000000  63.000000          63.000000
# mean   526.253968  524.761905  573.841270   0.651155          -0.200500
# std    115.045008  104.083669  149.841228   0.436343           1.075514
# ...

# %% [markdown]
# sucessful people = earning above 8 lack
#
# Thus by looking at the data we can say that
#
#     1.scoreing low in CollegeTier 1 will have more probablity of sucess than scoreing same in CollegeTier 2
#
#     2.Avg percetage of people earning more than 8 lakh in 10th = 79.5 and in 12th = 75
#
#     3.Avg gpa was 73.23
#
#     4.Minimum percetage of people earning more than 8 lakh in 10th = 53 and in 12th = 50 but they improved there college GPA TO 8.89
#
#     5.from psycological stand point average succesful people have agreeableness , extraversion  qualities.
#
#     6.from psycological stand point most succesful people have  conscientiousness ,agreeableness, extraversion,	          openess_to_experience qualities and have more score than average people

# %%
dfsucess.head()
# Out:
#             ID   Salary               Designation Gender  10percentage  \
# train   267447  1100000  senior software engineer      m         85.60
# train   361583   800000         software engineer      m         93.44
# train  1250429  1500000     application developer      m         79.00
# train   312164  1200000          engineer trainee      m         59.80
# train   323894  1860000            field engineer      f         89.70
#
#                      10board  12graduation  12percentage  \
# train                   cbse          2007         83.60
# train  karnataka state board          2008         90.00
# train            state board          2009         87.90
# train                   icse          2006         60.25
# train                      0          2007         89.60
#
#                      12board  CollegeTier          ...            \
# train                   cbse            1          ...
# train  karnataka state board            2          ...
# ...
