# %%
import pandas as pd

# %%
import numpy as np

# %%
import os

# %%
cwd = os.getcwd()

# %%
cwd
# Out:
# '/Users/shantanupatil/Desktop/Dataset/udise/state/raw/Elem'

# %%
os.chdir('/Users/shantanupatil/Desktop/Dataset/udise/state/raw/Elem')

# %%
os.listdir('.')
# Out:
# ['RawDataState2005',
#  'SRC RawData 2003-04',
#  'src_07',
#  'SRC_Raw Data_2010-11.xls',
#  'SRC_Raw_0708.xls',
#  'SRC_Raw_0809.xls',
#  'SRC_Raw_0910.xls',
#  'SRC_Rawdata_2011-12.rar',
#  'SRC_Rawdata_2011-13-1.rar',
#  'SRC_Rawdata_2013-14.rar',
#  'SRC_Rawdata_2014-15.xlsx',
#  'SRC_Rawdata_2015-16_Elementary.xlsx',
#  'State Report card Raw data 2005-06.xls']

# %%
file = 'SRC_Rawdata_2015-16_Elementary.xlsx'

# %%
xl = pd.ExcelFile(file)

# %%
print(xl.sheet_names)
# Out:
# ['2015-16_1', 'Sheet1', '2015-16_2', '2014-15_PY']

# %%
df1 = xl.parse('2015-16_1')

# %%
df1.head()
# Out:
#   Unnamed: 0                       Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0        NaN               Data Reported from        NaN        NaN
# 1        NaN      Basic data from Census 2011        NaN        NaN
# 2        NaN             Projected Population        NaN        NaN
# 3        NaN              Schools By Category        NaN          .
# 4        NaN  Schools by Category: Government        NaN        NaN
#
#   Unnamed: 4                                         Unnamed: 5 Unnamed: 6  \
# 0        NaN  Elementary Enrolment by School Category (Private)        NaN
# 1        NaN  Elementary Enrolment by School Category (Madar...        NaN
# 2        NaN  Elementary Enrolment by School Category (Gover...        NaN
# 3        NaN  Elementary Enrolment by School Category ( Priv...        NaN
# 4        NaN                           Single-Classroom Schools        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9     ...      Unnamed: 426 Unnamed: 427  \
# ...

# %%
df0 = df1.iloc[:,15:18]

# %%
df1 = df1[17:]

# %%
df1.head()
# Out:
#    Unnamed: 0 Unnamed: 1        Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 17        NaN     STATCD          STATNAME  DISTRICTS     BLOCKS   VILLAGES
# 18    2015-16         01   JAMMU & KASHMIR         22        201       7263
# 19    2015-16         02  HIMACHAL PRADESH         12        124      10120
# 20    2015-16         03            PUNJAB         22        146      13197
# 21    2015-16         04        CHANDIGARH          1         20         84
#
#    Unnamed: 6  Unnamed: 7 Unnamed: 8      Unnamed: 9     ...       \
# 17   CLUSTERS  TOTPOPULAT  P_URB_POP  POPULATION_0_6     ...
# 18       1628       12549      20.05           16.01     ...
# 19       2243        6857       8.69           11.14     ...
# 20       1780       27704      29.82           10.62     ...
# 21         20        1055      97.25           11.18     ...
#
#    Unnamed: 426 Unnamed: 427 Unnamed: 428 Unnamed: 429 Unnamed: 430  \
# ...

# %%
df1 = df1.rename(columns=df1.iloc[0])

# %%
df1.head()
# Out:
#         NaN  STATCD          STATNAME  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS  \
# 17      NaN  STATCD          STATNAME  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS
# 18  2015-16      01   JAMMU & KASHMIR         22     201      7263      1628
# 19  2015-16      02  HIMACHAL PRADESH         12     124     10120      2243
# 20  2015-16      03            PUNJAB         22     146     13197      1780
# 21  2015-16      04        CHANDIGARH          1      20        84        20
#
#     TOTPOPULAT  P_URB_POP  POPULATION_0_6     ...      TCH_TRNRM5  TCH_TRNRM6  \
# 17  TOTPOPULAT  P_URB_POP  POPULATION_0_6     ...      TCH_TRNRM5  TCH_TRNRM6
# 18       12549      20.05           16.01     ...               8         328
# 19        6857       8.69           11.14     ...             995           6
# 20       27704      29.82           10.62     ...            2215          13
# 21        1055      97.25           11.18     ...               0         109
#
# ...

# %%
df1=df1.set_index("STATCD")

# %% [markdown]
# ##

# %%
df1.head()
# Out:
#             NaN          STATNAME  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS  \
# STATCD
# STATCD      NaN          STATNAME  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS
# 01      2015-16   JAMMU & KASHMIR         22     201      7263      1628
# 02      2015-16  HIMACHAL PRADESH         12     124     10120      2243
# 03      2015-16            PUNJAB         22     146     13197      1780
# 04      2015-16        CHANDIGARH          1      20        84        20
#
#         TOTPOPULAT  P_URB_POP  POPULATION_0_6  GROWTHRATE     ...      \
# STATCD                                                        ...
# STATCD  TOTPOPULAT  P_URB_POP  POPULATION_0_6  GROWTHRATE     ...
# 01           12549      20.05           16.01       23.71     ...
# 02            6857       8.69           11.14       12.81     ...
# 03           27704      29.82           10.62       13.73     ...
# 04            1055      97.25           11.18        17.1     ...
#
# ...

# %%
df1.columns.values
# Out:
# array([nan, 'STATNAME', 'DISTRICTS', 'BLOCKS', 'VILLAGES', 'CLUSTERS',
#        'TOTPOPULAT', 'P_URB_POP', 'POPULATION_0_6', 'GROWTHRATE',
#        'SEXRATIO', 'P_SC_POP', 'P_ST_POP', 'OVERALL_LI', 'FEMALE_LIT',
#        'MALE_LIT', 'AREA_SQKM', 'TOT_6_10_15', 'TOT_11_13_15', 'SCH1',
#        'SCH2', 'SCH3', 'SCH4', 'SCH5', 'SCH6', 'SCH7', 'SCH9', 'SCHTOT',
#        'SCH1G', 'SCH2G', 'SCH3G', 'SCH4G', 'SCH5G', 'SCH6G', 'SCH7G',
#        'SCH9G', 'SCHTOTG', 'SCH1P', 'SCH2P', 'SCH3P', 'SCH4P', 'SCH5P',
#        'SCH6P', 'SCH7P', 'SCH9P', 'SCHTOTP', 'SCH1M', 'SCH2M', 'SCH3M',
#        'SCH4M', 'SCH5M', 'SCH6M', 'SCH7M', 'SCH9M', 'SCHTOTM', 'SCH1GR',
#        'SCH2GR', 'SCH3GR', 'SCH4GR', 'SCH5GR', 'SCH6GR', 'SCH7GR',
#        'SCH9GR', 'SCHTOTGR', 'SCH1GA', 'SCH2GA', 'SCH3GA', 'SCH4GA',
#        'SCH5GA', 'SCH6GA', 'SCH7GA', 'SCH9GA', 'SCHTOTGA', 'SCH1PR',
#        'SCH2PR', 'SCH3PR', 'SCH4PR', 'SCH5PR', 'SCH6PR', 'SCH7PR',
# ...

# %%
df1.head()
# Out:
#             NaN          STATNAME  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS  \
# STATCD
# STATCD      NaN          STATNAME  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS
# 01      2015-16   JAMMU & KASHMIR         22     201      7263      1628
# 02      2015-16  HIMACHAL PRADESH         12     124     10120      2243
# 03      2015-16            PUNJAB         22     146     13197      1780
# 04      2015-16        CHANDIGARH          1      20        84        20
#
#         TOTPOPULAT  P_URB_POP  POPULATION_0_6  GROWTHRATE     ...      \
# STATCD                                                        ...
# STATCD  TOTPOPULAT  P_URB_POP  POPULATION_0_6  GROWTHRATE     ...
# 01           12549      20.05           16.01       23.71     ...
# 02            6857       8.69           11.14       12.81     ...
# 03           27704      29.82           10.62       13.73     ...
# 04            1055      97.25           11.18        17.1     ...
#
# ...

# %%
state = df1.loc[:,'STATNAME']

# %%
state
# Out:
# STATCD
# STATCD                STATNAME
# 01             JAMMU & KASHMIR
# 02            HIMACHAL PRADESH
# 03                      PUNJAB
# 04                  CHANDIGARH
# 05                 UTTARAKHAND
# 06                     HARYANA
# 07                       DELHI
# 08                   RAJASTHAN
# 09               UTTAR PRADESH
# 10                       BIHAR
# 11                      SIKKIM
# 12           ARUNACHAL PRADESH
# 13                    NAGALAND
# 14                     MANIPUR
# 15                     MIZORAM
# 16                     TRIPURA
# 17                   MEGHALAYA
# 18                       ASSAM
# 19                 WEST BENGAL
# 20                   JHARKHAND
# 21                      ODISHA
# 22                CHHATTISGARH
# 23              MADHYA PRADESH
# 24                     GUJARAT
# 25                 DAMAN & DIU
# 26        DADRA & NAGAR HAVELI
# 27                 MAHARASHTRA
# 28              ANDHRA PRADESH
# 29                   KARNATAKA
# ...

# %%
df0.head()
# Out:
#    Unnamed: 0          Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 15    AC_YEAR  Data Reported from        NaN        NaN        NaN        NaN
# 16        NaN                 NaN        NaN        NaN        NaN        NaN
# 17        NaN              STATCD   STATNAME  DISTRICTS     BLOCKS   VILLAGES
#
#    Unnamed: 6                   Unnamed: 7                   Unnamed: 8  \
# 15        NaN  Basic data from Census 2011                          NaN
# 16        NaN  Total Population(in 1000's)  Percentage Urban Population
# 17   CLUSTERS                   TOTPOPULAT                    P_URB_POP
#
#                                 Unnamed: 9            ...             \
# 15                                     NaN            ...
# 16  Percentage Population of Age Group 0-6            ...
# 17                          POPULATION_0_6            ...
#
#                      Unnamed: 426                    Unnamed: 427  \
# ...

# %%
df1.shape
# Out:
# (37, 435)
