# %%
import pandas as pd
import numpy as np
import os
import scipy
cwd = os.getcwd()
os.chdir('/Users/shantanupatil/Desktop/Dataset/kaggle/')

# %%
os.listdir('.')
# Out:
# ["Mining Educational Data to Predict Student's academic Performance using Ensemble Methods (PDF Downlo.webarchive",
#  'Preprocessing and Analyzing Educational Data Set Using X-API for Improving Student’s Performance (PDF Download Available).pdf',
#  "Students' Academic Performance Dataset | Kaggle.webarchive",
#  'xAPI-Edu-Data.csv']

# %%
file =  'xAPI-Edu-Data.csv'

# %%
df = pd.read_csv(file)

# %%
df = df.drop(df.columns[[1,2,5]], axis = 1)

# %%
df.size
# Out:
# 6720

# %%
df.groupby('StageID').size()
# Out:
# StageID
# HighSchool       33
# MiddleSchool    248
# lowerlevel      199
# dtype: int64

# %%
df.groupby('GradeID').size()
# Out:
# GradeID
# G-02    147
# G-04     48
# G-05      3
# G-06     32
# G-07    101
# G-08    116
# G-09      5
# G-10      4
# G-11     13
# G-12     11
# dtype: int64

# %%
df.head()
# Out:
#   gender     StageID GradeID Topic Semester Relation  raisedhands  \
# 0      M  lowerlevel    G-04    IT        F   Father           15
# 1      M  lowerlevel    G-04    IT        F   Father           20
# 2      M  lowerlevel    G-04    IT        F   Father           10
# 3      M  lowerlevel    G-04    IT        F   Father           30
# 4      M  lowerlevel    G-04    IT        F   Father           40
#
#    VisITedResources  AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 0                16                  2          20                   Yes
# 1                20                  3          25                   Yes
# 2                 7                  0          30                    No
# 3                25                  5          35                    No
# 4                50                 12          50                    No
#
#   ParentschoolSatisfaction StudentAbsenceDays Class
# 0                     Good            Under-7     M
# ...

# %%
df2 = df

# %%
list(df2)
# Out:
# ['gender',
#  'StageID',
#  'GradeID',
#  'Topic',
#  'Semester',
#  'Relation',
#  'raisedhands',
#  'VisITedResources',
#  'AnnouncementsView',
#  'Discussion',
#  'ParentAnsweringSurvey',
#  'ParentschoolSatisfaction',
#  'StudentAbsenceDays',
#  'Class']

# %%
#df2 = df2.loc[:,['gender','raisedhands','VisITedResources','AnnouncementsView','Discussion','ParentAnsweringSurvey','StudentAbsenceDays','Class']]

# %%
df2
# Out:
#     gender       StageID GradeID      Topic Semester Relation  raisedhands  \
# 0        M    lowerlevel    G-04         IT        F   Father           15
# 1        M    lowerlevel    G-04         IT        F   Father           20
# 2        M    lowerlevel    G-04         IT        F   Father           10
# 3        M    lowerlevel    G-04         IT        F   Father           30
# 4        M    lowerlevel    G-04         IT        F   Father           40
# 5        F    lowerlevel    G-04         IT        F   Father           42
# 6        M  MiddleSchool    G-07       Math        F   Father           35
# 7        M  MiddleSchool    G-07       Math        F   Father           50
# 8        F  MiddleSchool    G-07       Math        F   Father           12
# 9        F  MiddleSchool    G-07         IT        F   Father           70
# 10       M  MiddleSchool    G-07       Math        F   Father           50
# ...

# %%
from sklearn.preprocessing import LabelEncoder
var_mod=[
 'gender',
 'StageID',
 'GradeID',
 'Topic',
 'Semester',
 'Relation',
 'ParentAnsweringSurvey',
 'ParentschoolSatisfaction',
 'StudentAbsenceDays',
 'Class'
    
]
le = LabelEncoder()
for i in var_mod:
    df.loc[:,i]= df.loc[:,i].factorize()[0]    
    df.loc[:,i]=le.fit_transform(df.loc[:,i])

# %%
cats=df
pValues=[]
for col in cats:
    groupsizes = df.groupby([col, 'Class']).size()
    #ctsum = groupsizes.unstack(col)
    ctsum.fillna(0, inplace=True)
    obs=ctsum.values
    p=scipy.stats.chi2_contingency(obs)[1]
    #pValues.append({col:float(p)*100})
    if p<0.05:
        pValues.append({col:['Dependent', float(p)*100]})
    else:
        pValues.append({col:['Independent', float(p)*100]})

# %%
pValues
# Out:
# [{'gender': ['Dependent', 1.2513960927832309e-47]},
#  {'StageID': ['Dependent', 1.2513960927832309e-47]},
#  {'GradeID': ['Dependent', 1.2513960927832309e-47]},
#  {'Topic': ['Dependent', 1.2513960927832309e-47]},
#  {'Semester': ['Dependent', 1.2513960927832309e-47]},
#  {'Relation': ['Dependent', 1.2513960927832309e-47]},
#  {'raisedhands': ['Dependent', 1.2513960927832309e-47]},
#  {'VisITedResources': ['Dependent', 1.2513960927832309e-47]},
#  {'AnnouncementsView': ['Dependent', 1.2513960927832309e-47]},
#  {'Discussion': ['Dependent', 1.2513960927832309e-47]},
#  {'ParentAnsweringSurvey': ['Dependent', 1.2513960927832309e-47]},
#  {'ParentschoolSatisfaction': ['Dependent', 1.2513960927832309e-47]},
#  {'StudentAbsenceDays': ['Dependent', 1.2513960927832309e-47]},
#  {'Class': ['Dependent', 1.2513960927832309e-47]}]

# %% [markdown]
# #chi square test used to find the relation of colums with column class

# %%
df.describe()
# Out:
#            gender     StageID     GradeID       Topic    Semester    Relation  \
# count  480.000000  480.000000  480.000000  480.000000  480.000000  480.000000
# mean     0.364583    0.654167    4.120833    4.402083    0.489583    0.410417
# std      0.481815    0.603732    3.560099    3.455472    0.500413    0.492423
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    1.000000    2.000000    0.000000    0.000000
# 50%      0.000000    1.000000    2.000000    4.000000    0.000000    0.000000
# 75%      1.000000    1.000000    9.000000    7.000000    1.000000    1.000000
# max      1.000000    2.000000    9.000000   11.000000    1.000000    1.000000
#
#        raisedhands  VisITedResources  AnnouncementsView  Discussion  \
# count   480.000000        480.000000         480.000000  480.000000
# mean     46.775000         54.797917          37.918750   43.283333
# ...

# %% [markdown]
#     1.The student who score maximum have above 7 abbsents
#     2.the parents who don't take part in survey or don't involve with school have children with low class marks and         low school satisfaction
#     3.

# %%
df
# Out:
#      gender  StageID  GradeID  Topic  Semester  Relation  raisedhands  \
# 0         0        0        0      0         0         0           15
# 1         0        0        0      0         0         0           20
# 2         0        0        0      0         0         0           10
# 3         0        0        0      0         0         0           30
# 4         0        0        0      0         0         0           40
# 5         1        0        0      0         0         0           42
# 6         0        1        1      1         0         0           35
# 7         0        1        1      1         0         0           50
# 8         1        1        1      1         0         0           12
# 9         1        1        1      0         0         0           70
# 10        0        1        1      1         0         0           50
# 11        0        1        1      1         0         0           19
# ...
