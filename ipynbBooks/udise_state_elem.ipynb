# %%
import pandas as pd

# %%
import xlrd

# %%
file_loc = '/Users/shantanupatil/Desktop/Dataset/udise/state/raw/Elem/SRC_Rawdata_2014-15.xlsx'

# %%
book = xlrd.open_workbook(file_loc)

# %%
book.nsheets
# Out:
# 5

# %%
book.sheet_names()
# Out:
# ['2014-15_1', 'Sheet1', '2014-15_2', '2014-15_PY', 'Sheet2']

# %%
first_s = book.sheet_by_index(0)

# %%
first_s.row_values(17)
# Out:
# ['AC_YEAR',
#  'Data Reported from',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Basic data from Census 2011',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Projected Population ',
#  '',
#  'Schools By Category',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Schools by Category: Government',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Schools by Category: Private ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Schools by Category: Madarsas & Unrecognised',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Government Schools by Category - Rural',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Schools by Category: Government & Aided ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Private Schools by Category - Rural',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Schools by Category: Boys Only',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
first_s.row_values(18)
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  "Total Population(in 1000's)",
#  'Percentage Urban Population',
#  'Percentage Population of Age Group 0-6',
#  'Growth Rate',
#  'Sex Ratio',
#  'Percentage SC Population',
#  'Percentage ST Population',
#  'Literacy Rate',
#  'Female Literacy Rate',
#  'Male Literacy Rate',
#  'Area (Sq. KM)',
#  'Age Group 6 to 10',
#  'Age Group 11 to 13',
#  'Primary Only',
#  'Primary with Upper Primary',
#  'Primary with upper Primary Sec/H.Sec',
#  'Upper Primary Only',
#  'Upper Primary with Sec./H.Sec',
#  'Primary with upper Primary Sec',
#  'Upper Primary with  Sec.',
#  'No Response',
#  'Total',
#  'Primary Only',
#  'Primary with Upper Primary',
#  'Primary with upper Primary Sec/H.Sec',
#  'Upper Primary Only',
#  'Upper Primary with Sec./H.Sec',
#  'Primary with upper Primary Sec',
#  'Upper Primary with  Sec.',
#  'No Response',
#  'Total',
#  'Primary Only',
#  'Primary with Upper Primary',
# ...

# %%
first_s.row_values(19)
# Out:
# ['',
#  'STATCD',
#  'STATNAME',
#  'DISTRICTS',
#  'BLOCKS',
#  'VILLAGES',
#  'CLUSTERS',
#  'TOTPOPULAT',
#  'P_URB_POP',
#  'POPULATION_0_6',
#  'GROWTHRATE',
#  'SEXRATIO',
#  'P_SC_POP',
#  'P_ST_POP',
#  'OVERALL_LI',
#  'FEMALE_LIT',
#  'MALE_LIT',
#  'AREA_SQKM',
#  'TOT_6_10_15',
#  'TOT_11_13_15',
#  'SCH1',
#  'SCH2',
#  'SCH3',
#  'SCH4',
#  'SCH5',
#  'SCH6',
#  'SCH7',
#  'SCH9',
#  'SCHTOT',
#  'SCH1G',
#  'SCH2G',
#  'SCH3G',
#  'SCH4G',
#  'SCH5G',
#  'SCH6G',
#  'SCH7G',
#  'SCH9G',
#  'SCHTOTG',
#  'SCH1P',
#  'SCH2P',
#  'SCH3P',
#  'SCH4P',
#  'SCH5P',
#  'SCH6P',
#  'SCH7P',
#  'SCH9P',
#  'SCHTOTP',
#  'SCH1M',
#  'SCH2M',
#  'SCH3M',
#  'SCH4M',
#  'SCH5M',
#  'SCH6M',
#  'SCH7M',
#  'SCH9M',
#  'SCHTOTM',
#  'SCH1GR',
#  'SCH2GR',
#  'SCH3GR',
#  'SCH4GR',
#  'SCH5GR',
#  'SCH6GR',
#  'SCH7GR',
#  'SCH9GR',
#  'SCHTOTGR',
#  'SCH1GA',
#  'SCH2GA',
#  'SCH3GA',
#  'SCH4GA',
#  'SCH5GA',
#  'SCH6GA',
#  'SCH7GA',
#  'SCH9GA',
#  'SCHTOTGA',
#  'SCH1PR',
# ...

# %%
#first_s.row_values()

# %%
cell =first_s.cell(0,0)

# %%
cell
# Out:
# empty:''

# %%
cells = first_s.row_slice(rowx=0,
                              start_colx=0,
                              end_colx=2)

# %%
for cell in cells:
    print(cell.value)
